# %%
import string
import random

# %%
class DesignTableFrame():
    def __init__(self):
        pass
    
    @property
    def genRandLetter(self):
        for i in range(0, 11):
            randLetter = random.choices(string.ascii_uppercase, k = 7)
            #print(" || ".join(randLetter))
            return randLetter

    @property
    def CreateTableFrame(self):
        tableframe = """
--------------------------------------------------
--------------------------------------------------
|| 04 Y || 05 X || 06 Y || 07 Z || 08 F || 09 H || 10 K ||
--------------------------------------------------
|| 11 A || 12 Z || 13 X || 14 Y || 15 Y || 16 C || 17 H ||
--------------------------------------------------
|| 18 H || 19 V || 20 T || 21 T || 22 R || 23 E || 24 C ||
--------------------------------------------------
|| 25 B || 26 Y || 27 H || 28 N || 29 Z || 30 V || 31 R ||
--------------------------------------------------
|| 32 D || 33 O || 34 S || 35 Z || 36 H || 37 A || 38 D ||
--------------------------------------------------
|| 39 N || 40 Q || 41 G || 42 K || 43 M || 44 L || 45 H ||
--------------------------------------------------
|| 46 R || 47 E || 48 D || 49 K || 50 A || 51 L || 52 B ||
--------------------------------------------------
|| 53 D || 54 H || 55 D || 56 B || 57 L || 58 U || 59 D ||
--------------------------------------------------
|| 60 C || 61 S || 62 T || 63 H || 64 N || 65 U || 66 Q ||
--------------------------------------------------
|| 67 F || 68 P || 69 E || 70 E || 71 F || 72 H || 73 B ||
--------------------------------------------------
|| 74 X || 75 D || 76 B || 77 P || 78 F || 79 L || 80 H ||
--------------------------------------------------
|| 81 F || 82 Y || 83 X || 84 U || 85 Y || 86 P || 87 V ||
--------------------------------------------------
--------------------------------------------------
"""
        return print(tableframe)

# %%
a = DesignTableFrame()
a.CreateTableFrame
# Out:
# --------------------------------------------------
# --------------------------------------------------
# || 04 Y || 05 X || 06 Y || 07 Z || 08 F || 09 H || 10 K ||
# --------------------------------------------------
# || 11 A || 12 Z || 13 X || 14 Y || 15 Y || 16 C || 17 H ||
# --------------------------------------------------
# || 18 H || 19 V || 20 T || 21 T || 22 R || 23 E || 24 C ||
# --------------------------------------------------
# || 25 B || 26 Y || 27 H || 28 N || 29 Z || 30 V || 31 R ||
# --------------------------------------------------
# || 32 D || 33 O || 34 S || 35 Z || 36 H || 37 A || 38 D ||
# --------------------------------------------------
# || 39 N || 40 Q || 41 G || 42 K || 43 M || 44 L || 45 H ||
# --------------------------------------------------
# || 46 R || 47 E || 48 D || 49 K || 50 A || 51 L || 52 B ||
# --------------------------------------------------
# || 53 D || 54 H || 55 D || 56 B || 57 L || 58 U || 59 D ||
# ...
